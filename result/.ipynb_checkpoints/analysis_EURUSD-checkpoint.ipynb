# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

raw = pd.read_csv('Backtest.csv')

df = raw.T
df.columns = df.iloc[0]
df = df[1:]
df.reset_index(drop=True, inplace=True)
df.rename

# Convert the numeric columns to float
numeric_columns = ['PnL', 'Fitness', 'TR', 'std(RR)', 'MDD', 'Win Rate', 'nTrade']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

strategy_mapping = {
    '0.002': 'STS1',
    '0.004': 'STS2',
    '0.005': 'STS3',
    '0.008': 'STS4'
}

data = df[df['Currency']=='EURUSD'].copy()
print(data)
for threshold, strategy in strategy_mapping.items():
    data.loc[data['Threshold'] == threshold, 'Strategy'] = strategy

avg_dict = dict()
        
def update_strategy_dict(df, strategy_dict):
    for strategy in df['Strategy'].unique():
        sub_df = df[df['Strategy']==strategy]
        strategy_dict.update({
            strategy: [
                np.mean(sub_df['PnL']), np.mean(sub_df['Fitness']),
                np.mean(sub_df['TR']), np.mean(sub_df['std(RR)']),
                np.mean(sub_df['MDD']), np.mean(sub_df['Win Rate']),
                np.mean(sub_df['nTrade'])
            ]
        })

update_strategy_dict(data, avg_dict)

avgdf = pd.DataFrame(avg_dict)
avgdf['Index'] = ['PnL','Fitness','TR','std(RR)','MDD','Win Rate','nTrade']
avgdf.set_index('Index', inplace=True)
# Out:
# Unnamed: 0 Currency Strategy    Time Threshold     PnL  Fitness      TR  \
# 0            EURUSD      B&H  202401      None -2453.0  -0.0222 -0.0222
# 1            EURUSD      RSI  202401      None -2406.0  -0.0219 -0.0219
# 2            EURUSD     MACD  202401      None -6232.0  -0.0570 -0.0570
# 3            EURUSD      STS  202401     0.002 -3036.0  -0.0278 -0.0278
# 4            EURUSD      STS  202401     0.004 -3282.0  -0.0300 -0.0300
# 5            EURUSD      STS  202401     0.005 -3146.0  -0.0288 -0.0288
# 6            EURUSD      STS  202401     0.008 -3407.0  -0.0312 -0.0312
# 7            EURUSD      MTS  202401       All  -589.0  -0.0053 -0.0053
# 8            EURUSD    MTSGA  202401       All -1079.0  -0.0098 -0.0098
# 9            EURUSD      B&H  202402      None     9.0   0.0001  0.0001
# 10           EURUSD      RSI  202402      None  -174.0  -0.0016 -0.0016
# 11           EURUSD     MACD  202402      None -4217.0  -0.0390 -0.0390
# 12           EURUSD      STS  202402     0.002  -458.0  -0.0042 -0.0042
# 13           EURUSD      STS  202402     0.004  -510.0  -0.0047 -0.0047
# 14           EURUSD      STS  202402     0.005  -570.0  -0.0053 -0.0053
# 15           EURUSD      STS  202402     0.008  -451.0  -0.0042 -0.0042
# 16           EURUSD      MTS  202402       All  1251.0   0.0116  0.0116
# 17           EURUSD    MTSGA  202402       All   815.0   0.0075  0.0075
# 18           EURUSD      B&H  202403      None  -127.0  -0.0012 -0.0012
# 19           EURUSD      RSI  202403      None  -942.0  -0.0086 -0.0086
# 20           EURUSD     MACD  202403      None -2754.0  -0.0253 -0.0253
# 21           EURUSD      STS  202403     0.002  1090.0   0.0100  0.0100
# 22           EURUSD      STS  202403     0.004  1196.0   0.0110  0.0110
# 23           EURUSD      STS  202403     0.005  1181.0   0.0109  0.0109
# 24           EURUSD      STS  202403     0.008  1300.0   0.0120  0.0120
# 25           EURUSD      MTS  202403       All  1434.0   0.0132  0.0132
# 26           EURUSD    MTSGA  202403       All  1891.0   0.0174  0.0174
# 27           EURUSD      B&H  202404      None -1277.0  -0.0118 -0.0118
# 28           EURUSD      RSI  202404      None -1072.0  -0.0099 -0.0099
# 29           EURUSD     MACD  202404      None -3535.0  -0.0329 -0.0329
# 30           EURUSD      STS  202404     0.002  1016.0   0.0095  0.0095
# 31           EURUSD      STS  202404     0.004   476.0   0.0045  0.0045
# 32           EURUSD      STS  202404     0.005   521.0   0.0049  0.0049
# 33           EURUSD      STS  202404     0.008   433.0   0.0040  0.0040
# 34           EURUSD      MTS  202404       All  1350.0   0.0126  0.0126
# 35           EURUSD    MTSGA  202404       All  2010.0   0.0188  0.0188
#
# Unnamed: 0  std(RR)     MDD  Win Rate  nTrade
# 0               NaN  0.0003    0.0000       1
# 1            0.0063  0.0001    0.2500       4
# 2            0.0006  0.0001    0.2883     437
# 3            0.0015  0.0001    0.3200      50
# 4            0.0013  0.0001    0.3000      50
# 5            0.0014  0.0001    0.3000      50
# 6            0.0013  0.0001    0.3000      50
# 7            0.0022  0.0001    0.3478      46
# 8            0.0021  0.0001    0.3800      50
# 9               NaN  0.0002    1.0000       1
# 10           0.0072  0.0002    0.3333       3
# 11           0.0006  0.0001    0.3048     374
# 12           0.0023  0.0001    0.5909      22
# 13           0.0022  0.0001    0.5000      22
# 14           0.0022  0.0001    0.5000      22
# 15           0.0023  0.0001    0.5000      22
# 16           0.0027  0.0001    0.6875      16
# 17           0.0021  0.0001    0.6522      23
# 18              NaN  0.0002    0.0000       1
# 19           0.0076  0.0002    0.3333       3
# 20           0.0005  0.0000    0.3020     298
# 21           0.0015  0.0000    0.6667      18
# 22           0.0014  0.0000    0.7222      18
# 23           0.0015  0.0000    0.7222      18
# 24           0.0014  0.0000    0.7222      18
# 25           0.0028  0.0000    0.5333      15
# 26           0.0023  0.0000    0.6667      21
# 27              NaN  0.0003    0.0000       1
# 28           0.0070  0.0002    0.5000       4
# 29           0.0008  0.0000    0.2985     268
# 30           0.0020  0.0000    0.5312      32
# 31           0.0015  0.0000    0.5625      32
# 32           0.0015  0.0000    0.5625      32
# 33           0.0015  0.0000    0.5625      32
# 34           0.0027  0.0001    0.5714      21
# 35           0.0021  0.0000    0.6667      33

# %%
import pandas as pd
from scipy.stats import skew, kurtosis

# 计算偏度和峰度，但使用 fisher=False 以获取实际的峰度值
selected_cols = ['TR', 'MDD', 'Win Rate']
strategies_USDCAD = data['Strategy'].unique()
skew_kurt_strategy_USDCAD = pd.DataFrame(columns=['Strategy', 'Column', 'Skewness', 'Kurtosis'])
for strategy in strategies_USDCAD:
    strategy_data = data[data['Strategy'] == strategy]
    for col in selected_cols:
        skew_val = skew(strategy_data[col].dropna())
        kurt_val = kurtosis(strategy_data[col].dropna(), fisher=False)
        skew_kurt_strategy_USDCAD = skew_kurt_strategy_USDCAD.append({
            'Strategy': strategy,
            'Column': col,
            'Skewness': skew_val,
            'Kurtosis': kurt_val
        }, ignore_index=True)
# Pivot the table for a better view
summary_table_USDCAD = skew_kurt_strategy_USDCAD.pivot_table(index='Strategy', columns='Column', values=['Skewness', 'Kurtosis'])
summary_table_USDCAD.columns = ['_'.join(col).strip() for col in summary_table_USDCAD.columns.values]
summary_table_USDCAD.reset_index(inplace=True)

# Display the summary table
summary_table_USDCAD
# Out:
#   Strategy  Kurtosis_MDD  Kurtosis_TR  Kurtosis_Win Rate  Skewness_MDD  \
# 0      B&H      1.000000     1.587774           2.333333 -8.077936e-16
# 1     MACD      1.000000     1.966895           2.015311  0.000000e+00
# 2      MTS      2.333333     2.318447           1.992050 -1.154701e+00
# 3    MTSGA      1.000000     1.903285           2.326874  0.000000e+00
# 4      RSI      2.333333     2.040737           2.097087 -1.154701e+00
# 5     STS1      1.000000     1.920691           2.026674  0.000000e+00
# 6     STS2      1.000000     2.006281           1.925623  0.000000e+00
# 7     STS3      1.000000     1.950961           1.925623  0.000000e+00
# 8     STS4      1.000000     2.036578           1.925623  0.000000e+00
#
#    Skewness_TR  Skewness_Win Rate
# 0    -0.447304           1.154701
# 1    -0.588232          -0.741020
# 2    -1.135863          -0.407323
# 3    -0.721555          -1.146671
# 4    -0.494585           0.652463
# 5    -0.744134          -0.691223
# 6    -0.743704          -0.190437
# 7    -0.696198          -0.190437
# 8    -0.746002          -0.190437

# %%
avgdf
# Out:
#                  B&H          RSI         MACD        STS1        STS2  \
# Index
# PnL      -962.000000 -1148.500000 -4184.500000 -347.000000 -530.000000
# Fitness    -0.008775    -0.010500    -0.038550   -0.003125   -0.004800
# TR         -0.008775    -0.010500    -0.038550   -0.003125   -0.004800
# std(RR)          NaN     0.007025     0.000625    0.001825    0.001600
# MDD         0.000250     0.000175     0.000050    0.000050    0.000050
# Win Rate    0.250000     0.354150     0.298400    0.527200    0.521175
# nTrade      1.000000     3.500000   344.250000   30.500000   30.500000
#
#                 STS3        STS4         MTS       MTSGA
# Index
# PnL      -503.500000 -531.250000  861.500000  909.250000
# Fitness    -0.004575   -0.004850    0.008025    0.008475
# TR         -0.004575   -0.004850    0.008025    0.008475
# std(RR)     0.001650    0.001625    0.002600    0.002150
# MDD         0.000050    0.000050    0.000075    0.000050
# Win Rate    0.521175    0.521175    0.535000    0.591400
# nTrade     30.500000   30.500000   24.500000   31.750000

# %% [markdown]
# # box-plot

# %%
# Define a function to analyze a given column
from scipy import stats

def analyze_column(data, column):
    strategies = data['Strategy'].unique()

    # Boxplot
    plt.figure(figsize=(12, 6))
    sns.boxplot(x='Strategy', y=column, data=data)
    plt.title(f'Boxplot of {column} in EURUSD market')
    plt.show()

    # ANOVA
    group_data = [data[data['Strategy'] == strategy][column].values for strategy in strategies]
    f_val, p_val = stats.f_oneway(*group_data)
    print(f"ANOVA for {column}: F={f_val}, p={p_val}")

    # Skewness and Kurtosis
    for strategy in strategies:
        skewness = stats.skew(data[data['Strategy'] == strategy][column])
        kurtosis = stats.kurtosis(data[data['Strategy'] == strategy][column])
        print(f"For {strategy}, {column}: skewness={skewness}, kurtosis={kurtosis}")

# %%
print(f"\n=== Analysis for Fitness ===")
analyze_column(data, 'Fitness')
# Out:
# === Analysis for Fitness ===
# ANOVA for Fitness: F=3.5426658200257046, p=0.006290967681300517
# For B&H, Fitness: skewness=-0.44730411247671953, kurtosis=-1.4122259135309931
# For RSI, Fitness: skewness=-0.49458526981685386, kurtosis=-0.95926293189597
# For MACD, Fitness: skewness=-0.5882318696035412, kurtosis=-1.0331046832073518
# For STS1, Fitness: skewness=-0.744133989790597, kurtosis=-1.07930875705782
# For STS2, Fitness: skewness=-0.7437044061545208, kurtosis=-0.9937185327676721
# For STS3, Fitness: skewness=-0.6961976450902986, kurtosis=-1.0490394833745889
# For STS4, Fitness: skewness=-0.7460015157334771, kurtosis=-0.9634223855674864
# For MTS, Fitness: skewness=-1.1358633601143884, kurtosis=-0.6815527891953743
# For MTSGA, Fitness: skewness=-0.7215554926456141, kurtosis=-1.0967146549541655

# %%
print(f"\n=== Analysis for TR ===")
analyze_column(data, 'TR')
# Out:
# === Analysis for TR ===
# ANOVA for TR: F=3.5426658200257046, p=0.006290967681300517
# For B&H, TR: skewness=-0.44730411247671953, kurtosis=-1.4122259135309931
# For RSI, TR: skewness=-0.49458526981685386, kurtosis=-0.95926293189597
# For MACD, TR: skewness=-0.5882318696035412, kurtosis=-1.0331046832073518
# For STS1, TR: skewness=-0.744133989790597, kurtosis=-1.07930875705782
# For STS2, TR: skewness=-0.7437044061545208, kurtosis=-0.9937185327676721
# For STS3, TR: skewness=-0.6961976450902986, kurtosis=-1.0490394833745889
# For STS4, TR: skewness=-0.7460015157334771, kurtosis=-0.9634223855674864
# For MTS, TR: skewness=-1.1358633601143884, kurtosis=-0.6815527891953743
# For MTSGA, TR: skewness=-0.7215554926456141, kurtosis=-1.0967146549541655

# %%
print(f"\n=== Analysis for MDD ===")
analyze_column(data[data['Strategy']!='B&H'], 'MDD')
# Out:
# === Analysis for MDD ===
# ANOVA for MDD: F=2.4571428571428577, p=0.04738289546239632
# For RSI, MDD: skewness=-1.1547005383792508, kurtosis=-0.6666666666666674
# For MACD, MDD: skewness=0.0, kurtosis=-2.0
# For STS1, MDD: skewness=0.0, kurtosis=-2.0
# For STS2, MDD: skewness=0.0, kurtosis=-2.0
# For STS3, MDD: skewness=0.0, kurtosis=-2.0
# For STS4, MDD: skewness=0.0, kurtosis=-2.0
# For MTS, MDD: skewness=-1.1547005383792517, kurtosis=-0.666666666666667
# For MTSGA, MDD: skewness=0.0, kurtosis=-2.0

# %%
print(f"\n=== Analysis for MDD ===")
analyze_column(data[data['Strategy']!='B&H'], 'Win Rate')
# Out:
# === Analysis for MDD ===
# ANOVA for Win Rate: F=1.9860547710457468, p=0.09945729252988218
# For RSI, Win Rate: skewness=0.6524628325557184, kurtosis=-0.9029127044862078
# For MACD, Win Rate: skewness=-0.7410201818823939, kurtosis=-0.984688816147214
# For STS1, Win Rate: skewness=-0.6912232937934373, kurtosis=-0.9733260610060084
# For STS2, Win Rate: skewness=-0.19043680536463456, kurtosis=-1.074376750082243
# For STS3, Win Rate: skewness=-0.19043680536463456, kurtosis=-1.074376750082243
# For STS4, Win Rate: skewness=-0.19043680536463456, kurtosis=-1.074376750082243
# For MTS, Win Rate: skewness=-0.40732335845447715, kurtosis=-1.0079496199040778
# For MTSGA, Win Rate: skewness=-1.1466709766154417, kurtosis=-0.6731260628673237

# %% [markdown]
# # Avg, Skewness, and Kurtosis

# %% [markdown]
# ## PnL

# %%
avgdf
# Out:
#                  B&H          RSI         MACD        STS1        STS2  \
# Index
# PnL      -962.000000 -1148.500000 -4184.500000 -347.000000 -530.000000
# Fitness    -0.008775    -0.010500    -0.038550   -0.003125   -0.004800
# TR         -0.008775    -0.010500    -0.038550   -0.003125   -0.004800
# std(RR)          NaN     0.007025     0.000625    0.001825    0.001600
# MDD         0.000250     0.000175     0.000050    0.000050    0.000050
# Win Rate    0.250000     0.354150     0.298400    0.527200    0.521175
# nTrade      1.000000     3.500000   344.250000   30.500000   30.500000
#
#                 STS3        STS4         MTS       MTSGA
# Index
# PnL      -503.500000 -531.250000  861.500000  909.250000
# Fitness    -0.004575   -0.004850    0.008025    0.008475
# TR         -0.004575   -0.004850    0.008025    0.008475
# std(RR)     0.001650    0.001625    0.002600    0.002150
# MDD         0.000050    0.000050    0.000075    0.000050
# Win Rate    0.521175    0.521175    0.535000    0.591400
# nTrade     30.500000   30.500000   24.500000   31.750000

# %%
unique_strategies = data['Strategy'].unique()

# Calculate skewness and kurtosis for PnL for each strategy
skewness_kurtosis = {strategy: {"skewness": stats.skew(data[data['Strategy'] == strategy]['PnL']),
                                 "kurtosis": stats.kurtosis(data[data['Strategy'] == strategy]['PnL'])} 
                     for strategy in unique_strategies}
skewness_kurtosis
# Out:
# {'B&H': {'skewness': -0.4686442688223279, 'kurtosis': -1.388064033321688},
#  'RSI': {'skewness': -0.5087440887843916, 'kurtosis': -0.9534481712687435},
#  'MACD': {'skewness': -0.626108438321009, 'kurtosis': -1.022292107047409},
#  'STS1': {'skewness': -0.747521235677966, 'kurtosis': -1.0750253887260282},
#  'STS2': {'skewness': -0.7466278553097151, 'kurtosis': -0.9885674080215163},
#  'STS3': {'skewness': -0.7025838829990805, 'kurtosis': -1.0410328299434741},
#  'STS4': {'skewness': -0.7523641316840392, 'kurtosis': -0.958666749867664},
#  'MTS': {'skewness': -1.134199357272794, 'kurtosis': -0.6825640304222476},
#  'MTSGA': {'skewness': -0.7340584452733415, 'kurtosis': -1.086015804226938}}

# %% [markdown]
# # PnL
# ## Hist

# %%
# Create histograms for PnL of each strategy
plt.figure(figsize=(15, 10))

for i, strategy in enumerate(unique_strategies, 1):
    plt.subplot(3, 3, i)
    sns.histplot(data[data['Strategy'] == strategy]['PnL'], bins=10, kde=True)
    plt.title(f'PnL Distribution for {strategy}')

plt.tight_layout()
plt.show()

# %%
# Create histograms for PnL of each strategy
plt.figure(figsize=(15, 10))

for i, strategy in enumerate(unique_strategies, 1):
    plt.subplot(3, 3, i)
    sns.histplot(data[data['Strategy'] == strategy]['TR'], bins=10, kde=True)
    plt.title(f'RoR Distribution for {strategy}')
    plt.xlabel('RoR')

    
plt.tight_layout()
plt.show()

# %%
# Create histograms for PnL of each strategy
plt.figure(figsize=(15, 10))

for i, strategy in enumerate(unique_strategies, 1):
    plt.subplot(3, 3, i)
    sns.histplot(data[data['Strategy'] == strategy]['MDD'], bins=10, kde=True)
    plt.title(f'MDD Distribution for {strategy}')
    plt.xlabel('MDD')

    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Kruskal-Wallis

# %%
# Perform Kruskal-Wallis test
kruskal_result = stats.kruskal(*[data[data['Strategy'] == strategy]['PnL'] for strategy in unique_strategies])

kruskal_result
# Out:
# KruskalResult(statistic=15.351351351351354, pvalue=0.05266309562400407)

# %% [markdown]
# ## M-W U Test

# %% [markdown]
# The Mann-Whitney U test is a non-parametric test that can be used to compare two independent samples. However, please note that performing multiple tests increases the likelihood of Type I errors (false positives), so a correction method such as the Bonferroni correction is usually applied to control the family-wise error rate.

# %%
from scipy.stats import mannwhitneyu
from itertools import combinations

# Get all combinations of strategies
strategy_combinations = list(combinations(unique_strategies, 2))

# Initialize an empty DataFrame to store the results
mann_whitney_results = pd.DataFrame(columns=['Group1', 'Group2', 'Statistic', 'p-value'])

# Perform Mann-Whitney U test for each pair of strategies
for group1, group2 in strategy_combinations:
    stat, p = mannwhitneyu(data[data['Strategy'] == group1]['PnL'], 
                           data[data['Strategy'] == group2]['PnL'],
                           alternative='two-sided')
    temp_df = pd.DataFrame({'Group1': [group1], 
                            'Group2': [group2], 
                            'Statistic': [stat], 
                            'p-value': [p]})
    mann_whitney_results = pd.concat([mann_whitney_results, temp_df])

# Apply Bonferroni correction
mann_whitney_results['p-value'] *= len(strategy_combinations)
mann_whitney_results['p-value'] = mann_whitney_results['p-value'].clip(upper=1)

# Display the results
mann_whitney_results.sort_values(by='p-value')
# Out:
#   Group1 Group2  Statistic  p-value
# 0    B&H    RSI        9.0      1.0
# 0   MACD  MTSGA        0.0      1.0
# 0   STS1   STS2        9.0      1.0
# 0   STS1   STS3        9.0      1.0
# 0   STS1   STS4        8.0      1.0
# 0   STS1    MTS        3.0      1.0
# 0   STS1  MTSGA        5.0      1.0
# 0   MACD    MTS        0.0      1.0
# 0   STS2   STS3        8.0      1.0
# 0   STS2    MTS        3.0      1.0
# 0   STS2  MTSGA        4.0      1.0
# 0   STS3   STS4        8.0      1.0
# 0   STS3    MTS        3.0      1.0
# 0   STS3  MTSGA        4.0      1.0
# 0   STS4    MTS        4.0      1.0
# 0   STS2   STS4        8.0      1.0
# 0   MACD   STS4        1.0      1.0
# 0   MACD   STS3        1.0      1.0
# 0   MACD   STS2        1.0      1.0
# 0    B&H   MACD       16.0      1.0
# 0    B&H   STS1        6.0      1.0
# 0    B&H   STS2        6.0      1.0
# 0    B&H   STS3        6.0      1.0
# 0    B&H   STS4        6.0      1.0
# 0    B&H    MTS        2.0      1.0
# 0    B&H  MTSGA        2.0      1.0
# 0    RSI   MACD       16.0      1.0
# 0    RSI   STS1        5.0      1.0
# 0    RSI   STS2        5.0      1.0
# 0    RSI   STS3        5.0      1.0
# 0    RSI   STS4        5.0      1.0
# 0    RSI    MTS        1.0      1.0
# 0    RSI  MTSGA        3.0      1.0
# 0   MACD   STS1        1.0      1.0
# 0   STS4  MTSGA        4.0      1.0
# 0    MTS  MTSGA        7.0      1.0

# %% [markdown]
# # Total Return (RoR)

# %%
# Check if the assumptions of normality and homogeneity of variances are met for 'TR'

# Normality
print("Shapiro-Wilk Test for Normality:")
for strategy in unique_strategies:
    _, p = stats.shapiro(data[data['Strategy'] == strategy]['TR'])
    print(f"{strategy}: p-value = {p}")

# Homogeneity of variances
_, p = stats.levene(*[data[data['Strategy'] == strategy]['TR'] for strategy in unique_strategies])
print(f"\nLevene's Test for Homogeneity of Variances: p-value = {p}")
# Out:
# Shapiro-Wilk Test for Normality:
# B&H: p-value = 0.41692686080932617
# RSI: p-value = 0.6650031805038452
# MACD: p-value = 0.7069768309593201
# STS1: p-value = 0.21956859529018402
# STS2: p-value = 0.47587624192237854
# STS3: p-value = 0.5163722038269043
# STS4: p-value = 0.49490177631378174
# MTS: p-value = 0.010700758546590805
# MTSGA: p-value = 0.3004210889339447
#
# Levene's Test for Homogeneity of Variances: p-value = 0.8942326763673218

# %%
# Perform Kruskal-Wallis test for 'MDD'
kruskal_result = stats.kruskal(*[data[data['Strategy'] == strategy]['TR'] for strategy in unique_strategies])

kruskal_result
# Out:
# KruskalResult(statistic=15.684217301750765, pvalue=0.04712950816418559)

# %% [markdown]
# ## ANOVA

# %%
# Perform ANOVA for 'TR'
anova_result = stats.f_oneway(*[data[data['Strategy'] == strategy]['TR'] for strategy in unique_strategies])

anova_result
# Out:
# F_onewayResult(statistic=3.5426658200257046, pvalue=0.006290967681300517)

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Perform Tukey's HSD test for 'TR'
tukey_result = pairwise_tukeyhsd(endog=data['TR'], groups=data['Strategy'], alpha=0.1)

# Convert the result to a DataFrame
tukey_df = pd.DataFrame(data=tukey_result._results_table.data[1:], columns=tukey_result._results_table.data[0])

# Display the results
tukey_df.sort_values(by='p-adj')
# Out:
#    group1 group2  meandiff   p-adj   lower   upper  reject
# 9    MACD  MTSGA    0.0470  0.0027  0.0157  0.0784    True
# 8    MACD    MTS    0.0466  0.0030  0.0152  0.0779    True
# 11   MACD   STS1    0.0354  0.0424  0.0041  0.0668    True
# 13   MACD   STS3    0.0340  0.0581  0.0026  0.0653    True
# 12   MACD   STS2    0.0338  0.0610  0.0024  0.0651    True
# 14   MACD   STS4    0.0337  0.0616  0.0024  0.0650    True
# 0     B&H   MACD   -0.0298  0.1356 -0.0611  0.0016   False
# 10   MACD    RSI    0.0280  0.1866 -0.0033  0.0594   False
# 21  MTSGA    RSI   -0.0190  0.6374 -0.0503  0.0124   False
# 16    MTS    RSI   -0.0185  0.6616 -0.0499  0.0128   False
# 2     B&H  MTSGA    0.0173  0.7303 -0.0141  0.0486   False
# 1     B&H    MTS    0.0168  0.7546 -0.0145  0.0481   False
# 29    RSI   STS4    0.0057  0.9000 -0.0257  0.0370   False
# 31   STS1   STS3   -0.0014  0.9000 -0.0328  0.0299   False
# 32   STS1   STS4   -0.0017  0.9000 -0.0331  0.0296   False
# 33   STS2   STS3    0.0002  0.9000 -0.0311  0.0316   False
# 28    RSI   STS3    0.0059  0.9000 -0.0254  0.0373   False
# 27    RSI   STS2    0.0057  0.9000 -0.0256  0.0370   False
# 26    RSI   STS1    0.0074  0.9000 -0.0240  0.0387   False
# 25  MTSGA   STS4   -0.0133  0.9000 -0.0447  0.0180   False
# 24  MTSGA   STS3   -0.0130  0.9000 -0.0444  0.0183   False
# 30   STS1   STS2   -0.0017  0.9000 -0.0330  0.0297   False
# 23  MTSGA   STS2   -0.0133  0.9000 -0.0446  0.0181   False
# 17    MTS   STS1   -0.0112  0.9000 -0.0425  0.0202   False
# 20    MTS   STS4   -0.0129  0.9000 -0.0442  0.0185   False
# 19    MTS   STS3   -0.0126  0.9000 -0.0439  0.0187   False
# 18    MTS   STS2   -0.0128  0.9000 -0.0442  0.0185   False
# 34   STS2   STS4   -0.0000  0.9000 -0.0314  0.0313   False
# 15    MTS  MTSGA    0.0004  0.9000 -0.0309  0.0318   False
# 7     B&H   STS4    0.0039  0.9000 -0.0274  0.0353   False
# 6     B&H   STS3    0.0042  0.9000 -0.0271  0.0355   False
# 5     B&H   STS2    0.0040  0.9000 -0.0274  0.0353   False
# 4     B&H   STS1    0.0057  0.9000 -0.0257  0.0370   False
# 3     B&H    RSI   -0.0017  0.9000 -0.0331  0.0296   False
# 22  MTSGA   STS1   -0.0116  0.9000 -0.0429  0.0197   False
# 35   STS3   STS4   -0.0003  0.9000 -0.0316  0.0311   False

# %%
tukey_df[tukey_df['reject']==True]
# Out:
#    group1 group2  meandiff   p-adj   lower   upper  reject
# 8    MACD    MTS    0.0466  0.0030  0.0152  0.0779    True
# 9    MACD  MTSGA    0.0470  0.0027  0.0157  0.0784    True
# 11   MACD   STS1    0.0354  0.0424  0.0041  0.0668    True
# 12   MACD   STS2    0.0338  0.0610  0.0024  0.0651    True
# 13   MACD   STS3    0.0340  0.0581  0.0026  0.0653    True
# 14   MACD   STS4    0.0337  0.0616  0.0024  0.0650    True

# %% [markdown]
# # MDD

# %%
# Check if the assumptions of normality and homogeneity of variances are met for 'MDD'

# Normality
print("Shapiro-Wilk Test for Normality:")
for strategy in unique_strategies:
    _, p = stats.shapiro(data[data['Strategy'] == strategy]['MDD'])
    print(f"{strategy}: p-value = {p}")

# Homogeneity of variances
_, p = stats.levene(*[data[data['Strategy'] == strategy]['MDD'] for strategy in unique_strategies])
print(f"\nLevene's Test for Homogeneity of Variances: p-value = {p}")
# Out:
# Shapiro-Wilk Test for Normality:
# B&H: p-value = 0.02385682798922062
# RSI: p-value = 0.001240724348463118
# MACD: p-value = 0.02385682798922062
# STS1: p-value = 0.02385682798922062
# STS2: p-value = 0.02385682798922062
# STS3: p-value = 0.02385682798922062
# STS4: p-value = 0.02385682798922062
# MTS: p-value = 0.001240724348463118
# MTSGA: p-value = 0.02385682798922062
#
# Levene's Test for Homogeneity of Variances: p-value = 0.5492892120496438

# %%
# Perform Kruskal-Wallis test for 'MDD'
kruskal_result = stats.kruskal(*[data[data['Strategy'] == strategy]['MDD'] for strategy in unique_strategies])

kruskal_result
# Out:
# KruskalResult(statistic=19.19258016405667, pvalue=0.013862971622828044)

# %%
# Initialize an empty DataFrame to store the results
mann_whitney_results = pd.DataFrame(columns=['Group1', 'Group2', 'Statistic', 'p-value'])

# Perform Mann-Whitney U test for each pair of strategies
for group1, group2 in strategy_combinations:
    stat, p = mannwhitneyu(data[data['Strategy'] == group1]['MDD'], 
                           data[data['Strategy'] == group2]['MDD'],
                           alternative='two-sided')
    temp_df = pd.DataFrame({'Group1': [group1], 
                            'Group2': [group2], 
                            'Statistic': [stat], 
                            'p-value': [p]})
    mann_whitney_results = pd.concat([mann_whitney_results, temp_df])

# Apply Bonferroni correction
mann_whitney_results['p-value'] *= len(strategy_combinations)
mann_whitney_results['p-value'] = mann_whitney_results['p-value'].clip(upper=1)

# Display the results
mann_whitney_results.sort_values(by='p-value')
# Out:
#   Group1 Group2  Statistic   p-value
# 0    B&H    MTS       16.0  0.887518
# 0    B&H   MACD       16.0  0.954674
# 0    B&H   STS1       16.0  0.954674
# 0    B&H   STS2       16.0  0.954674
# 0    B&H   STS3       16.0  0.954674
# 0    B&H   STS4       16.0  0.954674
# 0    B&H  MTSGA       16.0  0.954674
# 0    B&H    RSI       13.0  1.000000
# 0   STS1   STS4        8.0  1.000000
# 0   STS1    MTS        6.0  1.000000
# 0   STS1  MTSGA        8.0  1.000000
# 0   STS2   STS3        8.0  1.000000
# 0   STS2   STS4        8.0  1.000000
# 0   STS3    MTS        6.0  1.000000
# 0   STS2  MTSGA        8.0  1.000000
# 0   STS3   STS4        8.0  1.000000
# 0   STS1   STS3        8.0  1.000000
# 0   STS3  MTSGA        8.0  1.000000
# 0   STS4    MTS        6.0  1.000000
# 0   STS2    MTS        6.0  1.000000
# 0   STS1   STS2        8.0  1.000000
# 0   MACD   STS3        8.0  1.000000
# 0   MACD    MTS        6.0  1.000000
# 0   MACD   STS4        8.0  1.000000
# 0   STS4  MTSGA        8.0  1.000000
# 0   MACD   STS2        8.0  1.000000
# 0   MACD   STS1        8.0  1.000000
# 0    RSI  MTSGA       15.0  1.000000
# 0    RSI    MTS       14.5  1.000000
# 0    RSI   STS4       15.0  1.000000
# 0    RSI   STS3       15.0  1.000000
# 0    RSI   STS2       15.0  1.000000
# 0    RSI   STS1       15.0  1.000000
# 0    RSI   MACD       15.0  1.000000
# 0   MACD  MTSGA        8.0  1.000000
# 0    MTS  MTSGA       10.0  1.000000

# %%
mann_whitney_results[mann_whitney_results['Group2']=='MTSGA']
# Out:
#   Group1 Group2  Statistic   p-value
# 0    B&H  MTSGA       16.0  0.954674
# 0    RSI  MTSGA       15.0  1.000000
# 0   MACD  MTSGA        8.0  1.000000
# 0   STS1  MTSGA        8.0  1.000000
# 0   STS2  MTSGA        8.0  1.000000
# 0   STS3  MTSGA        8.0  1.000000
# 0   STS4  MTSGA        8.0  1.000000
# 0    MTS  MTSGA       10.0  1.000000
